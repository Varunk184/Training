# %%
class Node:
    def __init__(self,data):
        self.left = None
        self.data = data
        self.right = None
    def insert(self,data):
        if self.data:
            if data<self.data:
                if self.left is None:
                    self.left=Node(data)
                else:
                    self.left.insert(data)
            elif data>self.data:
                if self.right is None:
                    self.right=Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data=data
    def Display(self):
        if self.left:
            self.left.Display()
        print(self.data)
        if self.right:
            self.right.Display()
            
    def inOrder(root):
        if root is None:
            return
        inorder(root.left)
        print(root.data,end=" ")
        inorder(root.right)

# %%
root = Node(27)
root.insert(14)
root.insert(35)
root.insert(10)
root.insert(19)
root.insert(31)
root.insert(42)
root.Display()
print(root.inOrder())
# Out:
# 10
# 14
# 19
# 27
# 31
# 35
# 42
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4600/822483704.py in <module>
#       7 root.insert(42)
#       8 root.Display()
# ----> 9 print(root.inOrder())
#
# ~\AppData\Local\Temp/ipykernel_4600/2823003181.py in inOrder(root)
#      28         if root is None:
#      29             return
# ---> 30         inorder(root.left)
#      31         print(root.data,end=" ")
#      32         inorder(root.right)
#
# NameError: name 'inorder' is not defined

# %%
n = int(input())
arr = map(int,input().split())
c=list(arr)
c.sort()
print(c[n-2])

# %%
list1 = [10, 20, 4, 45, 99]
new_list = set(list1)
new_list.remove(max(new_list))
print(max(new_list))

# %%
n = int(input())
arr=map(int,input().split())
c=list(arr)
d = max(c)
for i in c:
    if i==d:
        i.remove
    
c.remove(max(c))

print(max(c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4600/1227910654.py in <module>
# ----> 1 n = int(input())
#       2 arr=map(int,input().split())
#       3 c=list(arr)
#       4 d = max(c)
#       5 for i in c:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def findLargest(c):
    secondLargest = 0
    largest = min(c)

    for i in range(len(c)):
        if c[i] > largest:
            secondLargest = largest
            largest = c[i]
        else:
            secondLargest = max(secondLargest, c[i])

    return secondLargest


n = int(input())
arr=map(int,input().split())
c=list(arr)
findLargest(c)

# %%
n = int(input())
arr = map(int,input().split())
c=list(arr)
 
mx = max(c[0],c[1])
secondmax = min(c[0],c[1])
for i in range(2,n):
    if c[i] > mx:
        secondmax = mx
        mx = c[i]
    elif c[i] > secondmax and \
        mx != c[i]:
        secondmax = c[i]
    elif mx == secondmax and \
        secondmax != c[i]:
          secondmax = c[i]
 
print(\
      str(secondmax))

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# D:\cr3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
os.chdir("C:/Users/varun/OneDrive/Desktop/python/Regression/linear reg")

# %%
a = pd.read_csv('iris.csv')

# %%
a
# Out:
#      sepal length  sepal width  petal length  petal width     class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a.head()
# Out:
#    sepal length  sepal width  petal length  petal width  class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
a[a['sepal length']>6 ]
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# ..            ...          ...           ...          ...         ...
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
#
# [61 rows x 5 columns]

# %%
a[a['petal length']>2]
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [100 rows x 5 columns]

# %%
a[a['sepal width']==3]
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 1             4.9          3.0           1.4          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 38            4.4          3.0           1.3          0.2      setosa
# 45            4.8          3.0           1.4          0.3      setosa
# 61            5.9          3.0           4.2          1.5  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor
# ...

# %%
sns.scatterplot(x='sepal length',y='petal length',data=a)
plt.plot()
# Out:
# []

# %%
sns.barplot(x='sepal length',y='sepal length',data=a)
plt.plot()
# Out:
# []

# %%
a.columns=[["sepal length","sepal width","petal length","petal width","species"]]

# %%
a.head()
# Out:
#   sepal length sepal width petal length petal width species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
x=a[['sepal length']]

# %%
y = a[['petal length']]

# %%
lr = LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#    sepal length
# 91          6.1
# 66          5.6
# 5           5.4
# 7           5.0
# 24          4.8

# %%
x_test.head()
# Out:
#     sepal length
# 28           5.2
# 78           6.0
# 105          7.6
# 143          6.8
# 39           5.1

# %%
y_train.head()
# Out:
#    petal length
# 91          4.6
# 66          4.5
# 5           1.7
# 7           1.5
# 24          1.9

# %%
y_test.head()
# Out:
#     petal length
# 28           1.4
# 78           4.5
# 105          6.6
# 143          5.9
# 39           1.5

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([[2.5039658 ],
#        [4.06768976],
#        [7.19513769],
#        [5.63141372],
#        [2.30850031],
#        [4.84955174],
#        [7.78153417],
#        [4.84955174],
#        [4.65408625],
#        [7.39060318],
#        [5.24048273],
#        [4.06768976],
#        [2.5039658 ],
#        [4.26315526],
#        [2.11303481],
#        [4.26315526],
#        [2.30850031],
#        [3.09036229],
#        [1.33117283],
#        [3.28582778],
#        [3.48129328],
#        [2.11303481],
#        [5.43594823],
#        [4.26315526],
#        [4.84955174],
#        [4.45862075],
#        [5.43594823],
#        [1.33117283],
#        [7.39060318],
#        [5.63141372],
#        [4.84955174],
#        [0.94024184],
#        [4.65408625],
#        [3.48129328],
#        [3.87222427],
#        [5.43594823],
#        [4.84955174],
#        [5.82687922],
#        [5.82687922],
#        [1.91756932],
#        [2.30850031],
#        [6.02234472],
#        [3.48129328],
# ...

# %%
x_train.head()
# Out:
#    sepal length
# 91          6.1
# 66          5.6
# 5           5.4
# 7           5.0
# 24          4.8

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 4.1742168126610615

# %%
x = a[['sepal width']]
y = a[['petal width']]

# %%
lrr = LinearRegression()

# %%
x_train,x_tesy,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
lrr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predd = lrr.predict(x_test)

# %%
y_predd
# Out:
# array([[-0.27227519],
#        [-0.79888255],
#        [-1.85209728],
#        [-1.32548992],
#        [-0.20644927],
#        [-1.06218624],
#        [-2.04957505],
#        [-1.06218624],
#        [-0.99636032],
#        [-1.91792321],
#        [-1.19383808],
#        [-0.79888255],
#        [-0.27227519],
#        [-0.86470847],
#        [-0.14062335],
#        [-0.86470847],
#        [-0.20644927],
#        [-0.46975295],
#        [ 0.12268034],
#        [-0.53557887],
#        [-0.60140479],
#        [-0.14062335],
#        [-1.259664  ],
#        [-0.86470847],
#        [-1.06218624],
#        [-0.93053439],
#        [-1.259664  ],
#        [ 0.12268034],
#        [-1.91792321],
#        [-1.32548992],
#        [-1.06218624],
#        [ 0.25433218],
#        [-0.99636032],
#        [-0.60140479],
#        [-0.73305663],
#        [-1.259664  ],
#        [-1.06218624],
#        [-1.39131584],
#        [-1.39131584],
#        [-0.07479742],
#        [-0.20644927],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
error = mean_squared_error(x_test,y_predd)

# %%
error
# Out:
# 49.64925504248202

# %%
import os 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
b = pd.read_csv('iris.csv')

# %%
b
# Out:
#      sepal length  sepal width  petal length  petal width     class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
b[b['petal width']>2]
# Out:
#      sepal length  sepal width  petal length  petal width     class
# 100           6.3          3.3           6.0          2.5  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# ...

# %%
b[b['sepal length']<5]
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 22            4.6          3.6           1.0          0.2      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# ...

# %%
y = b['sepal length']

# %%
x = b[['sepal width','petal length','petal width']]

# %%
sns.scatterplot(x='petal length',y='petal width',data=b,)
plt.show()

# %%
plt.scatter(x='petal length',y='petal width',data=b)
plt.show()

# %%
sns.barplot(x='petal length',y='petal width',data=b)
plt.plot()
# Out:
# []

# %%
x_trainn,x_testt,y_trainn,y_testt=train_test_split(x,y,train_size=0.3)

# %%
lr3 = LinearRegression()

# %%
lr3.fit(x_trainn,y_trainn)
# Out:
# LinearRegression()

# %%
y_preed=lr3.predict(x_testt)

# %%
y_pred[0:5]
# Out:
# array([5.99956071, 5.01712348, 4.95833865, 6.36355252, 4.71409259])

# %%
y_test.head(5)
# Out:
# 69     5.6
# 116    6.5
# 76     6.8
# 68     6.2
# 26     5.0
# Name: sepal length, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
e = mean_squared_error(y_testt,y_preed)

# %%
e
# Out:
# 0.11925813608651319

# %%
hot_encoding = pd.get_dummies(data=b)

# %%
hot_encoding[hot_encoding['sepal length']>6]
# Out:
#      sepal length  sepal width  petal length  petal width  class _setosa  \
# 50            7.0          3.2           4.7          1.4              0
# 51            6.4          3.2           4.5          1.5              0
# 52            6.9          3.1           4.9          1.5              0
# 54            6.5          2.8           4.6          1.5              0
# 56            6.3          3.3           4.7          1.6              0
# ..            ...          ...           ...          ...            ...
# 144           6.7          3.3           5.7          2.5              0
# 145           6.7          3.0           5.2          2.3              0
# 146           6.3          2.5           5.0          1.9              0
# 147           6.5          3.0           5.2          2.0              0
# 148           6.2          3.4           5.4          2.3              0
#
#      class _versicolor  class _virginica
# 50                   1                 0
# ...

# %%
b[b['sepal length']>6]
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# ..            ...          ...           ...          ...         ...
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
#
# [61 rows x 5 columns]
